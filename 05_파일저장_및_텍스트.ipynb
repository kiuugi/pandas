# %% [markdown]
# <a href="https://colab.research.google.com/github/kiuugi/pandas/blob/main/05_%ED%8C%8C%EC%9D%BC%EC%A0%80%EC%9E%A5_%EB%B0%8F_%ED%85%8D%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
# matplotlib 한글 처리

# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 41.0 MB/s eta 0:00:00
# ...
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

for fpath in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
  fm.fontManager.addfont(fpath)

plt.rc("font",family='NanumBarunGothic')

# %% [markdown]
# ### 파일저장

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y)
plt.savefig("/content/gdrive/MyDrive/Colab Notebooks/matplotlib/chart.png")

# %%
plt.plot(x,y)
plt.savefig("/content/gdrive/MyDrive/Colab Notebooks/matplotlib/chart.png", dpi=50)

# %% [markdown]
# ### 텍스트

# %%
plt.plot(x,y, marker='o')
for idx, txt in enumerate(y): # enumerate -> 인덱스 부여
  print(y[idx])
  plt.text(x[idx], y[idx] + 0.2, txt, ha='center',color='blue')
# Out:
# 2
# 4
# 8
