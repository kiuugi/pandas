# %% [markdown]
# <a href="https://colab.research.google.com/github/kiuugi/pandas/blob/main/01_%EA%B7%B8%EB%9E%98%ED%94%84_%EA%B8%B0%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## matplotlib (https://matplotlib.org)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리
# <img src='https://matplotlib.org/stable/_images/anatomy.png' width='700' height='600'>

# %%
# matplotlib 한글 처리
# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 19.7 MB/s eta 0:00:00
# ...
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import matplotlib.pyplot as plt
import numpy as np

import koreanize_matplotlib

# %%
# 선 차트
plt.plot?

# %% [markdown]
# ### 기본 차트 생성

# %% [markdown]
# ><b>리스트를 그래프로 나타내기</b>

# %%
#

x = [10, 20, 30, 40]
plt.plot(x) # ; 로그 출력 중지
g = plt.title("그래프")

# %%
#

x = [1,2,3,4]
y = [12,43,25,15]

g = plt.plot(x,y)

# %% [markdown]
# ><b>파이썬 딕셔너리를 그래프로 나타내기</b>

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot("data_x", "data_y", data=data_dict)

# %% [markdown]
# ### 타이틀 설정

# %%
plt.plot(x,y);
plt.title("꺽은 선 차트")
# Out:
# Text(0.5, 1.0, '꺽은 선 차트')

# %%
x = [1,2,3,4]
y = [12,-5,25,15]
plt.title("꺽은선 차트")
plt.plot(x,y);

# %% [markdown]
# ### 그리드

# %% [markdown]
# **전체설정**

# %%
plt.plot(x,y)
plt.grid()

# %% [markdown]
# **x축설정**

# %%
plt.plot(x,y)
plt.grid(axis="x")

# %% [markdown]
# **y축설정**

# %%
plt.plot(x,y)
plt.grid(axis="y")
